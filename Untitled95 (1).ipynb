# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import label_binarize,LabelEncoder,OneHotEncoder

# %%
data=pd.read_csv('titanic-passengers.csv',sep='\;')
data.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#    PassengerId Survived  Pclass  ...     Fare  Cabin  Embarked
# 0          343       No       2  ...  13.0000    NaN         S
# 1           76       No       3  ...   7.6500  F G73         S
# 2          641       No       3  ...   7.8542    NaN         S
# 3          568       No       3  ...  21.0750    NaN         S
# 4          672       No       1  ...  52.0000    B71         S
# 5          105       No       3  ...   7.9250    NaN         S
# 6          576       No       3  ...  14.5000    NaN         S
# 7          382      Yes       3  ...  15.7417    NaN         C
# ...

# %%
data.values
# Out:
# array([[343, 'No', 2, ..., 13.0, nan, 'S'],
#        [76, 'No', 3, ..., 7.65, 'F G73', 'S'],
#        [641, 'No', 3, ..., 7.8542, nan, 'S'],
#        ...,
#        [535, 'No', 3, ..., 8.6625, nan, 'S'],
#        [102, 'No', 3, ..., 7.8958, nan, 'S'],
#        [428, 'Yes', 2, ..., 26.0, nan, 'S']], dtype=object)

# %%
data_copy=data.copy()

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.shape
# Out:
# (891, 12)

# %%
d=data.columns[data.dtypes==np.object]
data[d].apply(lambda x:x.nunique())
# Out:
# Survived      2
# Name        891
# Sex           2
# Ticket      681
# Cabin       147
# Embarked      3
# dtype: int64

# %%
dummies_1=pd.get_dummies(data['Sex'],prefix="sex")
dummies_1

# %%
new_data=dummies.join(data_copy)
new_data.drop("Survived", axis=1,inplace=True)

# %%
new_col=dummies_1.join(new_data)
new_col.drop("Sex",axis=1,inplace=True)
new_col
# Out:
#      sex_female  sex_male  Survived_No  ...     Fare  Cabin  Embarked
# 0             0         1            1  ...  13.0000    NaN         S
# 1             0         1            1  ...   7.6500  F G73         S
# 2             0         1            1  ...   7.8542    NaN         S
# 3             1         0            1  ...  21.0750    NaN         S
# 4             0         1            1  ...  52.0000    B71         S
# ..          ...       ...          ...  ...      ...    ...       ...
# 886           1         0            0  ...  30.0708    NaN         C
# 887           0         1            1  ...   7.2292    NaN         C
# 888           1         0            1  ...   8.6625    NaN         S
# 889           0         1            1  ...   7.8958    NaN         S
# 890           1         0            0  ...  26.0000    NaN         S
#
# [891 rows x 14 columns]

# %%
le = LabelEncoder()

# %%
data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
new_col.drop("Name",axis=1)
new_col["Age"].fillna(25,inplace=True)
new_col
# Out:
#      sex_female  sex_male  Survived_No  ...     Fare  Cabin  Embarked
# 0             0         1            1  ...  13.0000    NaN         S
# 1             0         1            1  ...   7.6500  F G73         S
# 2             0         1            1  ...   7.8542    NaN         S
# 3             1         0            1  ...  21.0750    NaN         S
# 4             0         1            1  ...  52.0000    B71         S
# ..          ...       ...          ...  ...      ...    ...       ...
# 886           1         0            0  ...  30.0708    NaN         C
# 887           0         1            1  ...   7.2292    NaN         C
# 888           1         0            1  ...   8.6625    NaN         S
# 889           0         1            1  ...   7.8958    NaN         S
# 890           1         0            0  ...  26.0000    NaN         S
#
# [891 rows x 14 columns]

# %%
new_col['Embarked'].fillna("S", inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
transformers = ColumnTransformer([("Embarked", OneHotEncoder(), [0])], remainder = 'passthrough')
new_col["Embarked"]=transformers.fit_transform(new_col[["Embarked"]])
new_col
# Out:
#      sex_female  sex_male  Survived_No  ...     Fare  Cabin  Embarked
# 0             0         1            1  ...  13.0000    NaN       1.0
# 1             0         1            1  ...   7.6500  F G73       1.0
# 2             0         1            1  ...   7.8542    NaN       1.0
# 3             1         0            1  ...  21.0750    NaN       1.0
# 4             0         1            1  ...  52.0000    B71       1.0
# ..          ...       ...          ...  ...      ...    ...       ...
# 886           1         0            0  ...  30.0708    NaN       0.0
# 887           0         1            1  ...   7.2292    NaN       0.0
# 888           1         0            1  ...   8.6625    NaN       1.0
# 889           0         1            1  ...   7.8958    NaN       1.0
# 890           1         0            0  ...  26.0000    NaN       1.0
#
# [891 rows x 14 columns]

# %%
data['Fare'].plot()
